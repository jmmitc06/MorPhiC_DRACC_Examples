# %%
# Step 1 - convert the .raw to .mzML 
# you will need to update the notebook to point at the directory with the .raw files on your system


# !pip3 install pickleshare

# %cd /Users/mitchjo/ATLAS/HMGCS2
# !cp /Users/mitchjo/ATLAS/HMGCS2/convert.py /Users/mitchjo/Datasets/iPSC_Atlas_11_21_24/09202023_HMGCS2_Zukai_Supernatant/
# !cp /Users/mitchjo/ATLAS/HMGCS2/convert.py /Users/mitchjo/Datasets/iPSC_Atlas_11_21_24/09222023_HMGCS2_Zukai_Cellpellets/
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python3.13 -m pip install --upgrade pip
# /Users/mitchjo/Library/CloudStorage/OneDrive-TheJacksonLaboratory/Atlas_Materials/Code/Backend/ipsc_atlas_data_processing/HMGCS2

# %%
# %cd /Users/mitchjo/Datasets/iPSC_Atlas_11_21_24/09202023_HMGCS2_Zukai_Supernatant/
# !pwd
# !python3 convert.py
# Out:
# /Users/mitchjo/Datasets/iPSC_Atlas_11_21_24/09202023_HMGCS2_Zukai_Supernatant
# /Users/mitchjo/Datasets/iPSC_Atlas_11_21_24/09202023_HMGCS2_Zukai_Supernatant
# 2024-11-21 12:54:11 INFO Started parsing /Users/mitchjo/Datasets/iPSC_Atlas_11_21_24/09202023_HMGCS2_Zukai_Supernatant/HMGCS2_Supernatant_Sample12_RPpos_SZ_09202023_34.raw
# 2024-11-21 12:54:11 INFO Started parsing /Users/mitchjo/Datasets/iPSC_Atlas_11_21_24/09202023_HMGCS2_Zukai_Supernatant/HMGCS2_Supernatant_Sample27_RPpos_SZ_09202023_66.raw
# 2024-11-21 12:54:11 INFO Started parsing /Users/mitchjo/Datasets/iPSC_Atlas_11_21_24/09202023_HMGCS2_Zukai_Supernatant/HMGCS2_Supernatant_Sample1_HILICneg_SZ_09202023_09.raw
# 2024-11-21 12:54:11 INFO Started parsing /Users/mitchjo/Datasets/iPSC_Atlas_11_21_24/09202023_HMGCS2_Zukai_Supernatant/HMGCS2_Supernatant_Sample20_HILICneg_SZ_09202023_49.raw
# ...

# %%
# %cd /Users/mitchjo/Datasets/iPSC_Atlas_11_21_24/09222023_HMGCS2_Zukai_Cellpellets
# !pwd
# !python3 convert.py
# Out:
# /Users/mitchjo/Datasets/iPSC_Atlas_11_21_24/09222023_HMGCS2_Zukai_Cellpellets
# /Users/mitchjo/Datasets/iPSC_Atlas_11_21_24/09222023_HMGCS2_Zukai_Cellpellets
# 2024-11-21 13:07:27 INFO Started parsing /Users/mitchjo/Datasets/iPSC_Atlas_11_21_24/09222023_HMGCS2_Zukai_Cellpellets/HMGCS2_Cellpellets_Sample33_RPpos_SZ_09222023_80.raw
# 2024-11-21 13:07:27 INFO Started parsing /Users/mitchjo/Datasets/iPSC_Atlas_11_21_24/09222023_HMGCS2_Zukai_Cellpellets/HMGCS2_Cellpellets_Sample14_RPpos_SZ_09222023_38.raw
# 2024-11-21 13:07:27 INFO Started parsing /Users/mitchjo/Datasets/iPSC_Atlas_11_21_24/09222023_HMGCS2_Zukai_Cellpellets/HMGCS2_Cellpellets_Sample16_RPpos_SZ_09222023_42.raw
# 2024-11-21 13:07:27 INFO Started parsing /Users/mitchjo/Datasets/iPSC_Atlas_11_21_24/09222023_HMGCS2_Zukai_Cellpellets/Qstd_RPpos_1_SZ_09222023_06.raw
# ...

# %%
# %cd /Users/mitchjo/Datasets/iPSC_Atlas_11_21_24/09222023_HMGCS2_Zukai_Cellpellets
# !rm -rf *.raw
# Out:
# /Users/mitchjo/Datasets/iPSC_Atlas_11_21_24/09222023_HMGCS2_Zukai_Cellpellets
# /Users/mitchjo/Library/Python/3.11/lib/python/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# %cd /Users/mitchjo/Datasets/iPSC_Atlas_11_21_24/09202023_HMGCS2_Zukai_Supernatant/
# !rm -rf *.raw
# Out:
# /Users/mitchjo/Datasets/iPSC_Atlas_11_21_24/09202023_HMGCS2_Zukai_Supernatant
